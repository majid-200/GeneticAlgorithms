# %% [markdown]
# # Understanding the evolutionary part of the Genetic Algorithms

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Define the necessary helper functions.

# %%
def calc_fitness(chromosone, target_rgb):
    """
    Calculate the fitness of a given chromosome.

    Parameters:
        chromosome (np.ndarray): An array representing the chromosome.
        target_rgb (np.ndarray): The target RGB values.

    Returns:
        float: The mean absolute difference between the chromosome and target RGB values.
    """
    return np.mean(np.abs(chromosone - target_rgb))

# %%
def evolve_population(population, target_rgb, mutation_rate, elite_ratio):
    """
    Evolve a population of chromosomes.

    Parameters:
        population (List[np.ndarray]): A list of arrays representing the chromosomes in the population.
        target_rgb (np.ndarray): The target RGB values.
        mutation_rate (float): The probability of a chromosome mutating.
        elite_ratio (float): The ratio of chromosomes to be selected as elites.

    Returns:
        List[np.ndarray]: The evolved population of chromosomes.
    """
    # Calculate fitnes values for each chromosone in the population
    fitness_values = [calc_fitness(c, target_rgb) for c in population]

    # Select the chromosones with the best fitness values as elites
    elite_index = np.argsort(fitness_values)[:int(len(population) * elite_ratio)]
    elites = [population[i] for i in elite_index]

    # Create a new population by mating the elites
    new_population = []
    while len(new_population) < len(population) - len(elites):
        # Select two parents randomly from the elites
        parent1, parent2 = random.choices(elites, k=2)

        # Create a child chromosone by combining the gense of the 2 two parents
        child = np.zeros(parent1.shape)
        for i in range(len(parent1)):
            if random.random() < 0.5:
                child[i] = parent1[i]
            else:
                child[i] = parent2[i]

            # Mutate the childe chromosone with a probability determined by mutation_rate
            if random.random() < mutation_rate:
                child[i] = np.random.randint(0, 256)

        # Add the child chromosone to the population
        new_population.append(child)

    # Return the evolved population
    return elites + new_population

# %%
def simulate(size, target_rgb, generations, mutation_rate, elite_ratio):
    """
    Simulate the evolution of a population of chromosomes.

    Parameters:
        size (int): The size of the population.
        target_rgb (np.ndarray): The target RGB values.
        generations (int): The number of generations to evolve the population.
        mutation_rate (float): The probability of a chromosome mutating.
        elite_ratio (float): The ratio of chromosomes to be selected as elites.

    Returns:
        np.ndarray: The best chromosome found.
    """
    # Initialize the population with random RGB values
    population = [np.random.randint(0, 256, size=(3,)) for _ in range(size)]

    # Evolve the population over the specified number of generations
    for i in range(generations):
        # Evolve the population by selecting elites, mutating, and recombining
        population = evolve_population(population, target_rgb, mutation_rate, elite_ratio)

        # Get the individual with the best fitness (closest to target RGB)
        best_fit = min(population, key=lambda c: calc_fitness(c, target_rgb))

        # Print the generation number and the RGB values and fitness of the best individual
        print(f'Generation {i}: Best fitness {calc_fitness(best_fit, target_rgb)}, RGB values {best_fit}')

    # Return the individual with the minmum fitness value
    return best_fit

# %%
target_rgb = np.array([32, 154, 201])
best_camouflage = simulate(100, target_rgb, 50, 0.01, 0.1)

print("Target is %s and the best campuflage is %s ." % (target_rgb, best_camouflage))
# Out:
# <class 'numpy.ndarray'>
# Generation 0: Best fitness 3.0, RGB values [ 32. 146. 202.]
# <class 'numpy.ndarray'>
# Generation 1: Best fitness 3.0, RGB values [ 32. 146. 202.]
# <class 'numpy.ndarray'>
# Generation 2: Best fitness 3.0, RGB values [ 32. 146. 202.]
# <class 'numpy.ndarray'>
# Generation 3: Best fitness 3.0, RGB values [ 32. 146. 202.]
# <class 'numpy.ndarray'>
# Generation 4: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 5: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 6: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 7: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 8: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 9: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 10: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 11: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 12: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 13: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 14: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 15: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 16: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 17: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 18: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 19: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 20: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 21: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 22: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 23: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 24: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 25: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 26: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 27: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 28: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 29: Best fitness 1.3333333333333333, RGB values [ 32. 151. 202.]
# <class 'numpy.ndarray'>
# Generation 30: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 31: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 32: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 33: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 34: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 35: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 36: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 37: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 38: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 39: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 40: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 41: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 42: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 43: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 44: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 45: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 46: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 47: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 48: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# <class 'numpy.ndarray'>
# Generation 49: Best fitness 0.6666666666666666, RGB values [ 32. 153. 202.]
# Target is [ 32 154 201] and the best campuflage is [ 32. 153. 202.] .

# %%
# Create a figure and axis to plot the RGB values
fig, ax = plt.subplots(1, 2, figsize=(8, 4))

# Plot each RGB value in its own axis
ax[0].imshow(np.reshape(target_rgb/255, (1, 1, 3)))
ax[1].imshow(np.reshape(best_camouflage/255, (1, 1, 3)))

# Remove the axis labels and grid
ax[0].axis("off")
ax[1].axis("off")

#Add titles
ax[0].set_title("Target Color")
ax[1].set_title("Camouflage Color")
# Show the plot
plt.show()

# %% [markdown]
# # 2D image

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
def calc_fitness(chromosome, target_grid):
    """
    Calculates the fitness of a chromosome by comparing it to the target grid.

    Parameters:
        chromosome (np.array): The chromosome to calculate the fitness for.
        target_grid (np.array): The target grid to compare the chromosome to.

    Returns:
        float: The fitness of the chromosome.
    """
    return np.mean(np.abs(chromosome - target_grid))

# %%
def evolve_population(population, target_grid, mutation_rate, elite_ratio):
    """
    Evolves the population by selecting the best chromosomes (elites), breeding them, and mutating the offspring.

    Parameters:
        population (list of np.array): The current population of chromosomes.
        target_grid (np.array): The target grid to compare the chromosomes to.
        mutation_rate (float): The rate of mutation for the offspring.
        elite_ratio (float): The ratio of the population that should be considered as elites.

    Returns:
        list of np.array: The evolved population of chromosomes.
    """
    # Calculate fitness values for each chromosome in the population
    fitness_values = [calc_fitness(c, target_grid) for c in population]

    # Determine the indices of the best chromosomes (elites)
    elite_index = np.argsort(fitness_values)[:int(len(population) * elite_ratio)]

    # Select the best chromosomes (elites) from the population
    elites = [population[i] for i in elite_index]

    # Initialize the new population
    new_population = []

    # Create new offspring by breeding the elites
    while len(new_population) < len(population) - len(elites):
        # Select two parent chromosomes randomly from the elites
        parent1, parent2 = random.choices(elites, k=2)

        # Initialize the child chromosome
        child = np.zeros(parent1.shape)

        # Loop through the elements of the parent chromosomes
        for i in range(len(parent1)):
            for j in range(len(parent1[i])):
                for k in range(len(parent1[i][j])):
                    # Randomly inherit the element from either parent
                    if random.random() < 0.5:
                        child[i][j][k] = parent1[i][j][k]
                    else:
                        child[i][j][k] = parent2[i][j][k]

                    # Mutate the element with a certain probability
                    if random.random() < mutation_rate:
                        child[i][j][k] = np.random.randint(0, 256)

        # Add the child chromosome to the new population
        new_population.append(child)

    # Combine the elites and the offspring to form the evolved population
    return elites + new_population

# %%
def simulate(size, target_grid, generations, mutation_rate, elite_ratio):
    """
    This function simulates the evolutionary process to generate new images.

    Parameters:
    size (int) : The size of the population.
    target_grid (numpy array) : The target image for the evolutionary process.
    generations (int) : The number of generations to run the simulation for.
    mutation_rate (float) : The rate of mutation of the images in the population.
    elite_ratio (float) : The ratio of the population that will be considered as elites.

    Returns:
    (tuple) : A tuple of the best image generated by the simulation and a list of all images generated in the simulation.
    """
    images =[]
    # The size of each image in the population
    grid_size = (16, 16, 3)
    # initialize the population with random values
    population = [np.random.randint(0, 256, size=grid_size) for _ in range(size)]


    for i in range(generations):
      # evolve the population for each generation
        population = evolve_population(population, target_grid, mutation_rate, elite_ratio)
         # find the chromosome with the best fitness value
        best_fit = min(population, key=lambda c: calc_fitness(c, target_grid))
        # print the generation number and best fitness value
        print(f'Generation {i}: Best fitness {calc_fitness(best_fit, target_grid)}')

        # store the generated image
        images.append(best_fit.astype(np.uint8))

        # commented out code for displaying or saving images
        #fig, ax = plt.subplots()
        #ax.imshow(best_fit.astype(np.uint8))
        #plt.title(f'Generation {i}')
        #fig.tight_layout()
        #plt.show()
        # filename = f'camo_images/yellow/gen_{i}.png'
        # plt.savefig(filename)

    # Return the best fit image and the list of all images
    return min(population, key=lambda c: calc_fitness(c, target_grid)), images

# %%
target_grid = np.zeros((16, 16, 3), dtype=np.uint8)
#Yellow color from African Savannah [222, 165, 33]
# Green grass [0, 154, 23]
target_grid[:] = [32, 154, 201]

pop_size = 100
num_generations = 50
mut_rate = 0.01
elite_ratio = 0.1
best_camouflage, images = simulate(pop_size, target_grid, num_generations, mut_rate, elite_ratio)
# Out:
# Generation 0: Best fitness 76.83854166666667
# Generation 1: Best fitness 74.09765625
# Generation 2: Best fitness 71.97395833333333
# Generation 3: Best fitness 70.04427083333333
# Generation 4: Best fitness 68.77083333333333
# Generation 5: Best fitness 65.35807291666667
# Generation 6: Best fitness 64.86067708333333
# Generation 7: Best fitness 63.46484375
# Generation 8: Best fitness 61.66796875
# Generation 9: Best fitness 60.67578125
# Generation 10: Best fitness 59.505208333333336
# Generation 11: Best fitness 58.295572916666664
# Generation 12: Best fitness 57.557291666666664
# Generation 13: Best fitness 56.209635416666664
# Generation 14: Best fitness 55.56640625
# Generation 15: Best fitness 54.598958333333336
# Generation 16: Best fitness 53.994791666666664
# Generation 17: Best fitness 52.846354166666664
# Generation 18: Best fitness 51.8984375
# Generation 19: Best fitness 50.90234375
# Generation 20: Best fitness 50.432291666666664
# Generation 21: Best fitness 49.541666666666664
# Generation 22: Best fitness 49.041666666666664
# Generation 23: Best fitness 48.510416666666664
# Generation 24: Best fitness 47.967447916666664
# Generation 25: Best fitness 47.385416666666664
# Generation 26: Best fitness 46.87890625
# Generation 27: Best fitness 46.1328125
# Generation 28: Best fitness 45.997395833333336
# Generation 29: Best fitness 45.537760416666664
# Generation 30: Best fitness 44.649739583333336
# Generation 31: Best fitness 44.088541666666664
# Generation 32: Best fitness 43.990885416666664
# Generation 33: Best fitness 43.294270833333336
# Generation 34: Best fitness 42.631510416666664
# Generation 35: Best fitness 42.631510416666664
# Generation 36: Best fitness 42.1328125
# Generation 37: Best fitness 41.907552083333336
# Generation 38: Best fitness 41.7109375
# Generation 39: Best fitness 41.583333333333336
# Generation 40: Best fitness 41.102864583333336
# Generation 41: Best fitness 40.701822916666664
# Generation 42: Best fitness 40.354166666666664
# Generation 43: Best fitness 40.05859375
# Generation 44: Best fitness 39.891927083333336
# Generation 45: Best fitness 39.782552083333336
# Generation 46: Best fitness 39.264322916666664
# Generation 47: Best fitness 38.540364583333336
# Generation 48: Best fitness 38.26953125
# Generation 49: Best fitness 38.26953125

# %%
import numpy as np
import matplotlib.pyplot as plt

## Function to display a grid of images
def display_images(images, num_images=50, rows=10, cols=5):
    fig, axs = plt.subplots(rows, cols, figsize=(20, 20))
    for i, ax in enumerate(axs.ravel()):
        if i < num_images:
            ax.imshow(images[i], cmap='gray')
            ax.axis('off')
        else:
            fig.delaxes(ax)
    plt.tight_layout()
    plt.show()

# Plot images:

display_images(images, rows=5, cols=10)
